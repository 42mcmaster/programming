# %% [markdown]
# # prog06 Walkthrough — INSTRUCTOR SOLUTIONS
# **DO NOT DISTRIBUTE TO STUDENTS**
#
# This is the complete solutions version with all Try This exercises filled in.

# %% [markdown]
# ---
# ## Part 1: String Indexing & Slicing

# %%
# Example: Indexing
name = "Python"

print(f"First char: {name[0]}")
print(f"Third char: {name[2]}")
print(f"Last char: {name[-1]}")
print(f"Length: {len(name)}")

# %% [markdown]
# ### Try This: Index a different string

# %%
city = "Medina"

# Instructor Note: Students should get M, d, a
print(f"First: {city[0]}")
print(f"Middle (index 2): {city[2]}")
print(f"Last: {city[-1]}")

# %%
# Slicing examples
word = "Programming"

print(f"word[0:4] = {word[0:4]}")
print(f"word[4:] = {word[4:]}")
print(f"word[:7] = {word[:7]}")
print(f"word[::2] = {word[::2]}")
print(f"word[::-1] = {word[::-1]}")

# %% [markdown]
# ### Try This: Slice operations

# %%
text = "Algorithm"

# Instructor Note: Expected outputs:
# Alg, got, mhtirolA
print(f"First 3: {text[0:3]}")
print(f"Index 3 to 6: {text[3:6]}")
print(f"Reversed: {text[::-1]}")

# %% [markdown]
# ---
# ## Part 2: String Methods

# %%
# Case conversion
phrase = "Hello World"

print(f"Original: {phrase}")
print(f".upper(): {phrase.upper()}")
print(f".lower(): {phrase.lower()}")
print(f"Original unchanged: {phrase}")

# %%
# Whitespace handling
messy = "  JavaScript  \n"

print(f"Original: [{messy}]")
print(f".strip(): [{messy.strip()}]")
print(f".lstrip(): [{messy.lstrip()}]")
print(f".rstrip(): [{messy.rstrip()}]")

# %%
# Split and join
csv = "apple,banana,orange,grape"

fruits = csv.split(",")
print(f"Split by comma: {fruits}")

rejoined = " | ".join(fruits)
print(f"Joined with pipes: {rejoined}")

# %%
# Find, replace, count
sentence = "The quick brown fox jumps over the lazy dog"

print(f"Original: {sentence}")
print(f".find('quick'): {sentence.find('quick')}")
print(f".find('fox'): {sentence.find('fox')}")
print(f".count('the'): {sentence.count('the')}")

modified = sentence.replace("lazy", "sleepy")
print(f".replace(): {modified}")

# %%
# Checking start/end
url = "https://example.com"

print(f"URL: {url}")
print(f".startswith('https'): {url.startswith('https')}")
print(f".startswith('http:'): {url.startswith('http:')}")
print(f".endswith('.com'): {url.endswith('.com')}")
print(f".endswith('.org'): {url.endswith('.org')}")

# %% [markdown]
# ### Try This: String methods

# %%
sentence = "learn Python programming"

# Instructor Note: Multiple ways to do this
# 1. Uppercase
uppercase = sentence.upper()
print(f"Uppercase: {uppercase}")

# 2. Split
words = sentence.split()
print(f"Split: {words}")

# 3. Find
position = sentence.find("Python")
print(f"Position of 'Python': {position}")

# 4. Replace
replaced = sentence.replace("Python", "JavaScript")
print(f"Replaced: {replaced}")

# %% [markdown]
# ---
# ## Part 3: Lists — Creation & Access

# %%
# Create lists
numbers = [10, 20, 30, 40, 50]
mixed = ["Python", 3.14, True, 42]
empty = []

print(f"numbers: {numbers}")
print(f"mixed: {mixed}")
print(f"empty: {empty}")
print(f"Type of numbers: {type(numbers)}")

# %%
# Index and slice
scores = [85, 92, 78, 95, 88]

print(f"scores[0]: {scores[0]}")
print(f"scores[-1]: {scores[-1]}")
print(f"scores[1:4]: {scores[1:4]}")
print(f"scores[::2]: {scores[::2]}")

# %% [markdown]
# ### Try This: Create and access a list

# %%
# Instructor Note: Any 5 colors work. Middle index is 2 for a 5-item list.
colors = ["red", "green", "blue", "yellow", "purple"]

print(f"First: {colors[0]}")
print(f"Last: {colors[-1]}")
print(f"Middle: {colors[2]}")

# %% [markdown]
# ---
# ## Part 4: List Modification

# %%
# Add elements
basket = ["apple", "banana"]

print(f"Start: {basket}")
basket.append("orange")
print(f"After .append(): {basket}")

basket.insert(1, "grape")
print(f"After .insert(1, 'grape'): {basket}")

# %%
# Remove elements
items = ["a", "b", "c", "b", "d"]

print(f"Start: {items}")
items.remove("b")
print(f"After .remove('b'): {items}")

removed = items.pop()
print(f"After .pop(): {items}, popped: {removed}")

first = items.pop(0)
print(f"After .pop(0): {items}, popped: {first}")

# %%
# Sort and reverse
unsorted = [45, 12, 78, 23, 56]

print(f"Original: {unsorted}")
unsorted.sort()
print(f"After .sort(): {unsorted}")

unsorted.reverse()
print(f"After .reverse(): {unsorted}")

# %% [markdown]
# ### Try This: List modification

# %%
myList = [1, 2, 3, 4]

# Instructor Note: Step by step:
# 1. Add 5
myList.append(5)
print(f"After append(5): {myList}")

# 2. Insert 1.5 between 1 and 2 (at index 1)
myList.insert(1, 1.5)
print(f"After insert(1, 1.5): {myList}")

# 3. Remove 3
myList.remove(3)
print(f"After remove(3): {myList}")

# 4. Sort in descending order (reverse)
myList.sort(reverse=True)
print(f"After sort(reverse=True): {myList}")

# %% [markdown]
# ---
# ## Part 5: Looping & Comprehensions

# %%
# Loop through string
word = "code"

print("Characters in 'code':")
for char in word:
    print(f"  {char}")

# %%
# Loop through list (values)
colors = ["red", "green", "blue"]

print("Colors:")
for color in colors:
    print(f"  {color}")

# %%
# Loop through list (indices and values)
scores = [85, 92, 78]

print("Scores with indices:")
for i in range(len(scores)):
    print(f"  Index {i}: {scores[i]}")

# %%
# List comprehension
numbers = [1, 2, 3, 4, 5]

doubled = [x * 2 for x in numbers]
print(f"Original: {numbers}")
print(f"Doubled: {doubled}")

squared = [x ** 2 for x in numbers]
print(f"Squared: {squared}")

evens = [x for x in numbers if x % 2 == 0]
print(f"Even numbers: {evens}")

# %% [markdown]
# ### Try This: List comprehension

# %%
words = ["hello", "world", "python"]

# Instructor Note: Two equivalent approaches
# Approach 1: List comprehension
upperWords = [word.upper() for word in words]
print(f"Uppercase: {upperWords}")

# Approach 2: Regular loop (also acceptable)
upper2 = []
for w in words:
    upper2.append(w.upper())
print(f"Uppercase (loop): {upper2}")

# %% [markdown]
# ---
# ## Part 6: Useful List Methods

# %%
# Index and count
letters = ["a", "b", "c", "b", "d"]

print(f"List: {letters}")
print(f".index('b'): {letters.index('b')}")
print(f".count('b'): {letters.count('b')}")

print(f"'c' in letters: {'c' in letters}")
print(f"'z' in letters: {'z' in letters}")

# %% [markdown]
# ---
# ## Part 7: Nested Lists

# %%
# 2D structure
matrix = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

print(f"Full matrix: {matrix}")
print(f"Row 0: {matrix[0]}")
print(f"Element [0][1]: {matrix[0][1]}")
print(f"Element [2][2]: {matrix[2][2]}")

# %%
# Nested loop
for i in range(len(matrix)):
    for j in range(len(matrix[i])):
        print(f"[{i}][{j}] = {matrix[i][j]}")

# %% [markdown]
# ---
# ## Summary
#
# **Instructor Note**: All "Try This" sections completed. Ready for task notebooks.
