# %% [markdown]
# # prog06c Task: Data Processing with Strings & Lists
# ## Programming | Medina County Career Center
# **Instructor**: Ryan McMaster
#
# Apply string/list methods to real-world data problems.

# %% [markdown]
# ---
# ## Exercise 1: Word Frequency Counter
#
# Write a function `countWordFrequency(text)` that:
# 1. Takes a paragraph of text
# 2. Converts to lowercase and removes punctuation
# 3. Splits into words
# 4. Returns a dictionary with word counts
#
# **Example**:
# ```
# text = "Hello world! Hello Python. Python is fun."
# countWordFrequency(text)
# # Output: {'hello': 2, 'world': 1, 'python': 2, 'is': 1, 'fun': 1}
# ```

# %%
def countWordFrequency(text):
    # Your code here
    pass

# Test
sample = "Hello world! Hello Python. Python is fun."
result = countWordFrequency(sample)
print(result)

sample2 = "The quick brown fox jumps over the lazy dog."
print(countWordFrequency(sample2))

# %% [markdown]
# ---
# ## Exercise 2: Parse CSV Data
#
# Write a function `parseCSV(csvString)` that:
# 1. Takes a string with comma-separated values (one row per line)
# 2. Returns a list of lists (2D list, like a table)
# 3. Each inner list represents a row
#
# **Example**:
# ```
# csvString = """name,age,city
# Alice,30,Boston
# Bob,25,NYC
# Carol,28,LA"""
#
# parseCSV(csvString)
# # Output:
# # [
# #   ['name', 'age', 'city'],
# #   ['Alice', '30', 'Boston'],
# #   ['Bob', '25', 'NYC'],
# #   ['Carol', '28', 'LA']
# # ]
# ```

# %%
def parseCSV(csvString):
    # Your code here
    pass

# Test
csvData = """name,age,city
Alice,30,Boston
Bob,25,NYC
Carol,28,LA"""

result = parseCSV(csvData)
for row in result:
    print(row)

# %% [markdown]
# ---
# ## Exercise 3: Grade Book
#
# Create a class `GradeBook` with:
# 1. `__init__(self)` — initialize empty student list
# 2. `addStudent(name, grades)` — add student with list of grades
# 3. `getAverage(name)` — return average grade for student
# 4. `getClass Average()` — return average of all students
# 5. `getStudentNames()` — return list of all student names
#
# **Example**:
# ```
# gb = GradeBook()
# gb.addStudent("Alice", [90, 85, 88])
# gb.addStudent("Bob", [75, 80, 82])
# gb.getAverage("Alice")  # 87.67
# gb.getClassAverage()  # 83.33
# gb.getStudentNames()  # ["Alice", "Bob"]
# ```

# %%
class GradeBook:
    # Your code here
    pass

# Test
gb = GradeBook()
gb.addStudent("Alice", [90, 85, 88])
gb.addStudent("Bob", [75, 80, 82])
gb.addStudent("Carol", [95, 92, 98])

print(f"Alice's average: {gb.getAverage('Alice')}")
print(f"Bob's average: {gb.getAverage('Bob')}")
print(f"Class average: {gb.getClassAverage()}")
print(f"Students: {gb.getStudentNames()}")

# %% [markdown]
# ---
# ## Exercise 4: Text Statistics
#
# Write a function `textStats(text)` that returns a dictionary with:
# - 'char_count': total characters (including spaces)
# - 'word_count': total words
# - 'sentence_count': total sentences (count periods, question marks, exclamation marks)
# - 'avg_word_length': average characters per word
#
# **Example**:
# ```
# text = "Hello world! How are you? I am fine."
# textStats(text)
# # Output:
# # {
# #   'char_count': 38,
# #   'word_count': 8,
# #   'sentence_count': 3,
# #   'avg_word_length': 4.25
# # }
# ```

# %%
def textStats(text):
    # Your code here
    pass

# Test
sample = "Hello world! How are you? I am fine."
stats = textStats(sample)
for key, value in stats.items():
    print(f"{key}: {value}")

print()
sample2 = "Python is powerful."
stats2 = textStats(sample2)
for key, value in stats2.items():
    print(f"{key}: {value}")
