# %% [markdown]
# # prog06a Task: String Methods & Slicing
# ## Programming | Medina County Career Center
# **Instructor**: Ryan McMaster
#
# Practice string indexing, slicing, and methods.

# %% [markdown]
# ---
# ## Exercise 1: Reverse a String
#
# Write a function `reverseString(s)` that returns the string in reverse.
#
# **Examples**:
# - `reverseString("hello")` → `"olleh"`
# - `reverseString("Python")` → `"nohtyP"`

# %%
def reverseString(s):
    # Your code here
    pass

# Test
print(reverseString("hello"))
print(reverseString("Python"))
print(reverseString("racecar"))

# %% [markdown]
# ---
# ## Exercise 2: Count Vowels
#
# Write a function `countVowels(s)` that counts how many vowels (a, e, i, o, u) are in the string.
# Treat uppercase and lowercase as vowels (case-insensitive).
#
# **Examples**:
# - `countVowels("hello")` → `2`
# - `countVowels("beautiful")` → `5`
# - `countVowels("xyz")` → `0`

# %%
def countVowels(s):
    # Your code here
    pass

# Test
print(countVowels("hello"))
print(countVowels("beautiful"))
print(countVowels("xyz"))
print(countVowels("AEIOUaeiou"))

# %% [markdown]
# ---
# ## Exercise 3: Check Palindrome
#
# Write a function `isPalindrome(s)` that returns `True` if the string reads the same forwards and backwards.
# Ignore spaces and treat as case-insensitive.
#
# **Examples**:
# - `isPalindrome("racecar")` → `True`
# - `isPalindrome("hello")` → `False`
# - `isPalindrome("A man a plan a canal Panama")` → `True` (ignoring spaces)

# %%
def isPalindrome(s):
    # Your code here
    pass

# Test
print(isPalindrome("racecar"))
print(isPalindrome("hello"))
print(isPalindrome("A man a plan a canal Panama"))
print(isPalindrome("Madam"))

# %% [markdown]
# ---
# ## Exercise 4: Extract Initials
#
# Write a function `getInitials(name)` that extracts the first letter of each word and returns them as uppercase.
#
# **Examples**:
# - `getInitials("John Quincy Adams")` → `"JQA"`
# - `getInitials("ryan mcmaster")` → `"RM"`

# %%
def getInitials(name):
    # Your code here
    pass

# Test
print(getInitials("John Quincy Adams"))
print(getInitials("ryan mcmaster"))
print(getInitials("Mary Jane Watson"))

# %% [markdown]
# ---
# ## Exercise 5: Simple Encryption (Caesar Shift)
#
# Write a function `caesarShift(s, shift)` that shifts each character in the string by a given amount.
# For simplicity, only shift lowercase letters a-z (wrap around). Leave other characters unchanged.
#
# **Examples**:
# - `caesarShift("hello", 1)` → `"ifmmp"` (h→i, e→f, l→m, l→m, o→p)
# - `caesarShift("xyz", 3)` → `"abc"` (wraps around)
# - `caesarShift("hello 123", 5)` → `"mjqqt 123"` (spaces and numbers unchanged)

# %%
def caesarShift(s, shift):
    result = ""
    
    # Your code here
    
    return result

# Test
print(caesarShift("hello", 1))
print(caesarShift("xyz", 3))
print(caesarShift("hello 123", 5))
print(caesarShift("abc", 26))  # Full rotation

# %% [markdown]
# ---
# ## Bonus Challenge
#
# Write a function `removeVowels(s)` that returns a new string with all vowels removed.
#
# **Example**:
# - `removeVowels("Hello World")` → `"Hll Wrld"`

# %%
def removeVowels(s):
    # Your code here
    pass

# Test
print(removeVowels("Hello World"))
print(removeVowels("Programming"))
print(removeVowels("aeiou"))
