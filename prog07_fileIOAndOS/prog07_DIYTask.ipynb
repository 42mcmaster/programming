# %% [markdown]
# # Lesson 07: DIY Task — Student Grade Manager
# ## Programming | Medina County Career Center
# ### Instructor: Ryan McMaster
#
# **Independent Challenge** — Build a complete application that reads student data, performs analysis, and generates a report.

# %% [markdown]
# ## Setup: Create Sample Student Data
# Run this cell to create the `grades.csv` file.

# %%
# Create sample student data file
with open('grades.csv', 'w') as f:
    f.write('Name,Quiz1,Quiz2,Quiz3,Midterm,Final\n')
    f.write('Alice,85,90,92,88,95\n')
    f.write('Bob,78,82,80,75,85\n')
    f.write('Charlie,92,95,93,90,98\n')
    f.write('Diana,88,91,89,86,92\n')
    f.write('Eve,81,83,85,79,88\n')

print('grades.csv created successfully!')

# %% [markdown]
# ---
# ## Project Description: Student Grade Manager
#
# You will create a program that:
#
# 1. **Reads** a CSV file containing student names and their grades (5 grades per student)
# 2. **Calculates** for each student:
#    - Average grade
#    - Letter grade (A=90+, B=80-89, C=70-79, D=60-69, F=<60)
# 3. **Finds**:
#    - Overall class average
#    - Highest performing student
#    - Lowest performing student
#    - How many students got an A, B, C, D, F
# 4. **Writes** a formatted report to `grade_report.txt` with:
#    - Student name, average, letter grade
#    - Class statistics
#    - Grade distribution
#
# ---
#
# ## Example Output File (grade_report.txt)
# ```
# ========== STUDENT GRADE REPORT ==========
# Generated: 2024-01-15 14:30:00
#
# INDIVIDUAL GRADES
# Name           Average  Grade
# =======================================
# Alice          90.00    A
# Bob            80.00    B
# Charlie        93.60    A
# Diana          89.20    B
# Eve            83.20    B
#
# CLASS STATISTICS
# Class Average: 87.20
# Highest: Charlie (93.60)
# Lowest: Bob (80.00)
#
# GRADE DISTRIBUTION
# A (90+):  2 students
# B (80-89): 3 students
# C (70-79): 0 students
# D (60-69): 0 students
# F (<60):  0 students
#
# ===========================================
# ```

# %% [markdown]
# ---
# ## Step 1: Read the CSV File
#
# Write code to read `grades.csv` and display the data.

# %%
# Your code here
# Open grades.csv
# Read all lines (skip header)
# For each line, extract student name and grades
# Store in a data structure (list of dictionaries or similar)

# Display what you read
print('Data from grades.csv:')
# Display each student's data

# %% [markdown]
# ---
# ## Step 2: Calculate Student Averages and Letter Grades
#
# For each student, calculate:
# - Average of their 5 grades
# - Letter grade based on average

# %%
# Your code here
# Create a function to convert numeric average to letter grade
def getLetterGrade(average):
    # A: 90+, B: 80-89, C: 70-79, D: 60-69, F: <60
    # Your code here
    pass

# For each student, calculate average and letter grade
# Display the results

print('Student Grades:')
# Name, Average, Letter Grade

# %% [markdown]
# ---
# ## Step 3: Calculate Class Statistics
#
# Calculate:
# - Class average (average of all student averages)
# - Highest performing student
# - Lowest performing student
# - Grade distribution (count of A's, B's, C's, etc.)

# %%
# Your code here
# Calculate class average
# Find highest and lowest students
# Count grade distribution

classAverage = 0
highestStudent = ''
highestAverage = 0
lowestStudent = ''
lowestAverage = 100
gradeDistribution = {'A': 0, 'B': 0, 'C': 0, 'D': 0, 'F': 0}

print('\nClass Statistics:')
print(f'Class Average: {classAverage:.2f}')
print(f'Highest: {highestStudent} ({highestAverage:.2f})')
print(f'Lowest: {lowestStudent} ({lowestAverage:.2f})')
print(f'\nGrade Distribution: {gradeDistribution}')

# %% [markdown]
# ---
# ## Step 4: Write Formatted Report to File
#
# Create a nicely formatted report file (`grade_report.txt`) with all information.

# %%
# Your code here
from datetime import datetime

# Open grade_report.txt for writing
# Write header with title and timestamp
# Write individual student grades
# Write class statistics
# Write grade distribution
# Write footer

print('Report written to grade_report.txt')

# %% [markdown]
# ---
# ## Step 5: Verify the Report
#
# Read and display the report file to verify it was created correctly.

# %%
# Your code here
# Check if grade_report.txt exists
# If it does, read and display it
# If not, print an error message

import os

if os.path.exists('grade_report.txt'):
    print('Report Content:')
    print('=' * 50)
    # Read and display the report
else:
    print('ERROR: grade_report.txt not found')

# %% [markdown]
# ---
# ## Checklist
#
# - [ ] Read `grades.csv` successfully
# - [ ] Calculate individual student averages
# - [ ] Convert numeric grade to letter grade
# - [ ] Calculate class average
# - [ ] Find highest and lowest students
# - [ ] Count grade distribution (A, B, C, D, F)
# - [ ] Write formatted report to `grade_report.txt`
# - [ ] Report includes all required information
# - [ ] Output is properly formatted and readable
# - [ ] Used file I/O best practices (with statement, error checking)
#
# ---
#
# ## Tips
#
# 1. **Data Structure**: Store student data as a list of dictionaries with keys: name, grades (list), average, letterGrade
# 2. **Letter Grade Function**: Create a function that returns the letter grade based on numeric average
# 3. **Formatting**: Use f-strings and format specifiers (e.g., `{average:.2f}`) for decimal places
# 4. **File Operations**: Always use `with open()` statement
# 5. **Error Handling**: Check if files exist before reading with `os.path.exists()`
# 6. **Testing**: Run each step independently to verify it works before moving to the next step
