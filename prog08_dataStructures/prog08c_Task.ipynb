# %% [markdown]
# # Lesson 08c: Nested Data Structures Task
#
# **Course:** CTE Programming
# **School:** Medina County Career Center
# **Instructor:** Ryan McMaster
#
# In this task, you will work with nested data structures to manage a student records system.
# This is similar to working with database records.
#
# ---

# %% [markdown]
# ## Task: Student Records System
#
# You are building a student records system for a high school. Create functions to:
#
# 1. **Add a student** to the records (with name, grade level, and GPA)
# 2. **Compute the class average** GPA
# 3. **Find students on the honor roll** (GPA >= 3.5)
# 4. **Print a formatted report** of all students
# 5. **Search for a student** by name
# 6. **Update a student's GPA**
#
# Each student is a dictionary with keys: 'name', 'grade', 'gpa'
# All students are stored in a list of dictionaries (nested structure).

# %%
# Initialize the student records list
students = []

def addStudent(name, grade, gpa):
    """
    Add a new student to the records.
    Creates a dictionary for the student and appends to the list.
    """
    # Your code here
    pass

def computeClassAverage():
    """
    Compute the average GPA of all students.
    Return the average as a float.
    Handle the case of no students.
    """
    # Your code here
    pass

def findHonorRoll(minGPA=3.5):
    """
    Find all students with GPA >= minGPA (default 3.5).
    Return a list of student dictionaries.
    """
    # Your code here
    pass

def printStudentReport():
    """
    Print a formatted report of all students.
    Format: Name (Grade X) - GPA: X.XX
    Also print class statistics.
    """
    # Your code here
    pass

def searchStudent(name):
    """
    Search for a student by name (case-insensitive).
    Return the student dictionary if found, or None.
    """
    # Your code here
    pass

def updateStudentGPA(name, newGPA):
    """
    Update a student's GPA by name (case-insensitive).
    Return True if successful, False if student not found.
    """
    # Your code here
    pass

# Test the system
# Your test code here

# %% [markdown]
# **Expected Output:**
# ```
# Added Alice
# Added Bob
# Added Charlie
# Added David
#
# === Student Report ===
# Alice (Grade 10) - GPA: 3.80
# Bob (Grade 11) - GPA: 3.50
# Charlie (Grade 10) - GPA: 3.90
# David (Grade 12) - GPA: 3.20
#
# Total Students: 4
# Class Average GPA: 3.60
#
# === Honor Roll (GPA >= 3.5) ===
# Alice (Grade 10) - GPA: 3.80
# Bob (Grade 11) - GPA: 3.50
# Charlie (Grade 10) - GPA: 3.90
#
# Found Alice: {'name': 'Alice', 'grade': 10, 'gpa': 3.8}
# Updated David's GPA to 3.45
#
# === Updated Report ===
# Alice (Grade 10) - GPA: 3.80
# Bob (Grade 11) - GPA: 3.50
# Charlie (Grade 10) - GPA: 3.90
# David (Grade 12) - GPA: 3.45
# Class Average GPA: 3.66
# ```

# %% [markdown]
# ---
#
# ## Challenge Extensions (Optional)
#
# If you finish early, implement these additional features:
#
# 1. **Filter by grade level:** Return all students in a specific grade (9, 10, 11, or 12)
# 2. **Sort by GPA:** Return a list of students sorted by GPA (highest first)
# 3. **Statistics by grade:** Compute average GPA for each grade level
# 4. **Remove a student:** Delete a student from records by name
# 5. **Export to CSV:** Write student records to a CSV file
# 6. **Import from list:** Initialize students from a provided list of tuples

# %% [markdown]
# ## Reflection Questions
#
# 1. Why is a list of dictionaries better than separate lists for names and GPAs?
# 2. How would you modify the code to handle duplicate student names?
# 3. What happens if you call `computeClassAverage()` with no students?
# 4. How could you use a dictionary instead of a list for storing students (keyed by name)?
