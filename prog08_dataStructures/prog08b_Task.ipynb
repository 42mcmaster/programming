# %% [markdown]
# # Lesson 08b: Tuples, Sets, and Choosing Data Structures Task
#
# **Course:** CTE Programming
# **School:** Medina County Career Center
# **Instructor:** Ryan McMaster
#
# In this task, you will practice working with tuples and sets through three problems:
# 1. Coordinate distance calculator using tuples
# 2. Remove duplicates from a list using sets
# 3. Find common elements between two lists using set operations
#
# ---

# %% [markdown]
# ## Task 1: Coordinate Distance Calculator
#
# Use tuples to represent 2D coordinates. Create functions to:
# 1. Calculate the distance between two points
# 2. Determine if a point is within a certain distance of another point
# 3. Find the closest point to a reference point from a list of points
#
# Formula for distance between two points: `distance = sqrt((x2 - x1)^2 + (y2 - y1)^2)`

# %%
import math

def calculateDistance(point1, point2):
    """
    Calculate the Euclidean distance between two points.
    Points are tuples: (x, y)
    """
    # Your code here
    # Unpack the tuples
    # Calculate distance using the formula
    pass

def isWithinDistance(point1, point2, maxDistance):
    """
    Check if point2 is within maxDistance of point1.
    Return True or False.
    """
    # Your code here
    pass

def findClosestPoint(referencePoint, pointList):
    """
    Find the closest point to the reference point from a list.
    Return a tuple: (closest_point, distance)
    """
    # Your code here
    pass

# Test the functions
# Your test code here

# %% [markdown]
# **Expected Output:**
# ```
# Distance between (0, 0) and (3, 4): 5.0
# Distance between (1, 1) and (4, 5): 5.0
# Is (1, 1) within 3 units of (0, 0)? False
# Is (1, 1) within 2 units of (0, 0)? True
# Closest point to (0, 0): (1, 1) at distance 1.41
# ```

# %% [markdown]
# ## Task 2: Remove Duplicates Using Sets
#
# Create a function that removes duplicate values from a list. Use sets to:
# 1. Remove duplicates while preserving the unique elements
# 2. Count how many duplicates were removed
# 3. Find elements that appear more than once
# 4. Return a list of unique elements in sorted order

# %%
def removeDuplicates(itemList):
    """
    Remove duplicates from a list.
    Return a list of unique items.
    """
    # Your code here
    pass

def countDuplicatesRemoved(itemList):
    """
    Count how many duplicate items were in the list.
    Return the number of duplicates removed.
    """
    # Your code here
    # Hint: original_count - unique_count
    pass

def findDuplicateElements(itemList):
    """
    Find elements that appear more than once in the list.
    Return a set of duplicated elements.
    """
    # Your code here
    # Hint: use two loops or track seen elements
    pass

def getUniqueSorted(itemList):
    """
    Return a sorted list of unique elements.
    """
    # Your code here
    pass

# Test the functions
# Your test code here

# %% [markdown]
# **Expected Output:**
# ```
# Original list: [1, 2, 3, 2, 1, 4, 5, 4, 3]
# Unique items: {1, 2, 3, 4, 5}
# Duplicates removed: 4
# Elements that appear more than once: {1, 2, 3, 4}
# Sorted unique: [1, 2, 3, 4, 5]
# ```

# %% [markdown]
# ## Task 3: Find Common Elements Using Set Operations
#
# Use set operations (union, intersection, difference) to:
# 1. Find common elements between two lists (intersection)
# 2. Find all unique elements from both lists (union)
# 3. Find elements that are in the first list but not the second (difference)
# 4. Find elements unique to each list (symmetric difference)

# %%
def findCommonElements(list1, list2):
    """
    Find elements that appear in both lists.
    Return a set of common elements.
    """
    # Your code here
    # Use set intersection: set1 & set2
    pass

def findAllUniqueElements(list1, list2):
    """
    Find all unique elements from both lists (no duplicates).
    Return a set of all elements.
    """
    # Your code here
    # Use set union: set1 | set2
    pass

def findOnlyInFirst(list1, list2):
    """
    Find elements that are in list1 but not in list2.
    Return a set of elements.
    """
    # Your code here
    # Use set difference: set1 - set2
    pass

def findUniqueToEach(list1, list2):
    """
    Find elements that are unique to each list (not in both).
    Return a set of unique elements.
    """
    # Your code here
    # Use symmetric difference: set1 ^ set2
    pass

# Test the functions
# Your test code here

# %% [markdown]
# **Expected Output:**
# ```
# List 1: [1, 2, 3, 4, 5]
# List 2: [4, 5, 6, 7, 8]
#
# Common elements: {4, 5}
# All unique elements: {1, 2, 3, 4, 5, 6, 7, 8}
# Only in List 1: {1, 2, 3}
# Only in List 2: {6, 7, 8}
# Unique to each: {1, 2, 3, 6, 7, 8}
# ```

# %% [markdown]
# ---
#
# ## Bonus Challenge: When to Use Each Data Structure
#
# For each scenario below, decide which data structure to use: **list**, **tuple**, **set**, or **dict**.
# Explain your reasoning.
#
# 1. Storing student ID numbers and names
# 2. Storing a fixed sequence of RGB color values (Red, Green, Blue)
# 3. Storing a collection of student IDs that should never be modified
# 4. Storing student grades that need to be changed
# 5. Finding the common students enrolled in two classes
# 6. Storing coordinates of visited locations
#
# Write your answers below:

# %% [markdown]
# ## Reflection Questions
#
# 1. Why is a tuple better than a list for representing a coordinate point?
# 2. How do set operations make finding common elements easier?
# 3. When would you use a tuple as a dictionary key instead of a string?
# 4. What is the difference between removing duplicates and finding duplicate elements?
