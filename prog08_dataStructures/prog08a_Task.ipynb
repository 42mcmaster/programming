# %% [markdown]
# # Lesson 08a: Dictionaries Task
#
# **Course:** CTE Programming
# **School:** Medina County Career Center
# **Instructor:** Ryan McMaster
#
# In this task, you will practice working with Python dictionaries through three real-world problems:
# 1. A phone book application (add, lookup, delete contacts)
# 2. A word frequency counter
# 3. A simple phrase translator
#
# ---

# %% [markdown]
# ## Task 1: Phone Book Application
#
# Create a simple phone book system using a dictionary. Implement functions to:
# - Add a contact
# - Look up a contact by name
# - Delete a contact
# - List all contacts
#
# Store contacts as a dictionary where the key is the name and the value is the phone number.

# %%
# Initialize the phone book
phoneBook = {}

# Function to add a contact
def addContact(name, phoneNumber):
    """Add a contact to the phone book."""
    # Your code here
    pass

# Function to look up a contact
def lookupContact(name):
    """Look up a contact by name. Return the phone number or 'Not found'."""
    # Your code here
    pass

# Function to delete a contact
def deleteContact(name):
    """Delete a contact from the phone book."""
    # Your code here
    pass

# Function to list all contacts
def listAllContacts():
    """Print all contacts in the phone book."""
    # Your code here
    pass

# Test the phone book
# Your test code here

# %% [markdown]
# **Expected Output:**
# ```
# Added Alice
# Added Bob
# Alice's number: 330-555-1234
# Bob's number: 330-555-5678
# David not found
# All Contacts:
#   Alice: 330-555-1234
#   Bob: 330-555-5678
# Deleted Alice
# Alice not found
# ```

# %% [markdown]
# ## Task 2: Word Frequency Counter
#
# Create a program that counts the frequency of each word in a sentence or text. Use a dictionary where:
# - Key: word (convert to lowercase)
# - Value: count of occurrences
#
# Steps:
# 1. Take a string input
# 2. Split it into words
# 3. Count occurrences of each word
# 4. Display the results sorted by frequency (highest first)

# %%
def countWordFrequency(text):
    """
    Count the frequency of each word in the text.
    Return a dictionary with words as keys and counts as values.
    """
    # Initialize an empty dictionary
    wordCount = {}
    
    # Your code here
    # 1. Convert text to lowercase
    # 2. Remove punctuation (if needed) and split into words
    # 3. For each word, add it to the dictionary or increment its count
    
    return wordCount

# Test the function
sampleText = "the quick brown fox jumps over the lazy dog and the dog barks at the fox"
frequency = countWordFrequency(sampleText)

# Display results
# Your code here to print frequency dictionary
# Then sort and print by frequency (highest first)

# %% [markdown]
# **Expected Output:**
# ```
# Word Frequency Count:
# the: 4
# dog: 2
# fox: 2
# quick: 1
# brown: 1
# jumps: 1
# over: 1
# lazy: 1
# and: 1
# barks: 1
# at: 1
# ```

# %% [markdown]
# ## Task 3: Simple Phrase Translator
#
# Create a translator that converts English phrases to Spanish (or another language). Use a dictionary to store translations:
# - Key: English phrase
# - Value: Translation
#
# Implement:
# 1. A translation dictionary with at least 10 phrases
# 2. A function to translate a phrase (case-insensitive)
# 3. A function to add new translations
# 4. A function to list all translations

# %%
# Initialize the translation dictionary
translator = {
    'hello': 'hola',
    'goodbye': 'adiós',
    'thank you': 'gracias',
    'please': 'por favor',
    'good morning': 'buenos días',
    'good night': 'buenas noches',
    # Add more translations as needed
}

def translatePhrase(englishPhrase):
    """Translate an English phrase to Spanish."""
    # Your code here
    # Use .get() to safely look up the phrase (case-insensitive)
    # Return the translation or a message if not found
    pass

def addTranslation(englishPhrase, spanishPhrase):
    """Add a new translation to the dictionary."""
    # Your code here
    pass

def listAllTranslations():
    """Display all translations."""
    # Your code here
    pass

# Test the translator
# Your test code here

# %% [markdown]
# **Expected Output:**
# ```
# Translating 'hello': hola
# Translating 'goodbye': adiós
# Translating 'cat': Not found in dictionary
# Added 'cat': gato
# Translating 'cat': gato
#
# All Translations:
#   hello: hola
#   goodbye: adiós
#   thank you: gracias
#   please: por favor
#   good morning: buenos días
#   good night: buenas noches
#   cat: gato
# ```

# %% [markdown]
# ---
#
# ## Summary
#
# In this task, you practiced:
# - Creating and modifying dictionaries
# - Using `.get()` for safe lookups
# - Looping through dictionaries with `.items()`
# - Real-world applications: phone book, word frequency, translator
#
# **Reflection Questions:**
# 1. Why is a dictionary better than a list for the phone book?
# 2. How would you modify the word counter to ignore punctuation?
# 3. What happens if you try to look up a key that doesn't exist? How did you handle it?
