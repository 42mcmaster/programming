# %% [markdown]
# # Task 09: BPA Mock Contest (Solutions)

# %% [markdown]
# ## Problem 1: Sum of Digits

# %%
def mockContest_problem1(n):
    digit_sum = sum(int(d) for d in str(n))
    print(digit_sum)

mockContest_problem1(12345)
# Out:
# 15
