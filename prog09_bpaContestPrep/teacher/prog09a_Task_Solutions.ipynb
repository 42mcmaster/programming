# %% [markdown]
# # Task 09a: Error Handling Exercises (Solutions)
#
# **Objective:** Master try/except blocks, input validation, and defensive programming.

# %% [markdown]
# ## Exercise 1: Basic try/except

# %%
def getAge():
    try:
        age = int(input('Enter your age: '))
        print(f'You are {age} years old.')
    except ValueError:
        print('Error: Please enter a valid integer for age.')

# Instructor Note: Simple error handling.
