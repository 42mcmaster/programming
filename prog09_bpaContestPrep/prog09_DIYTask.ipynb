# %% [markdown]
# # Task 09: BPA Mock Contest (Independent)
#
# **Objective:** Simulate real BPA contest conditions. You are on your own.
#
# **Instructions:**
# - 5 timed problems
# - Suggested time: 45 minutes total (~9 min per problem)
# - Start your timer NOW

# %% [markdown]
# ## Problem 1: Sum of Digits
#
# **Description:** Given a positive integer, find the sum of its digits.
#
# **Example:**
# ```
# Input: 12345
# Output: 15
# ```

# %%
def mockContest_problem1():
    # Your code here
    pass
