# %% [markdown]
# # Task 09b: Algorithm Practice
#
# **Objective:** Implement core contest algorithms.

# %% [markdown]
# ## Algorithm 1: Prime Number Checker
#
# **Requirements:**
# - Return True if n is prime, False otherwise
# - Handle edge cases: numbers less than 2
# - Optimize: only check divisors up to sqrt(n)

# %%
def isPrime(n):
    # Your code here
    pass

# Test cases
# print(isPrime(2))   # Expected: True
