# %% [markdown]
# # Task 09a: Error Handling Exercises
#
# **Objective:** Master try/except blocks, input validation, and defensive programming.
#
# **Instructions:** Complete each exercise. Test with both valid and invalid input.

# %% [markdown]
# ## Exercise 1: Basic try/except
#
# Wrap the following code in a try/except block to handle ValueError when the user enters non-numeric input.
#
# **Requirements:**
# - Catch ValueError
# - Print an error message if input is invalid
# - Do not crash

# %%
def getAge():
    # Your code here
    pass

# Test (uncomment to run interactively)
# getAge()

# %% [markdown]
# ## Exercise 2: Input Validation Function
#
# Write a function that repeatedly asks the user for a number between 1 and 10 until they provide valid input.

# %%
def getNumberInRange():
    # Your code here
    pass

# Test
# num = getNumberInRange()

# %% [markdown]
# ## Reflection
#
# Answer these questions:
#
# 1. **Why is error handling important in a contest?**
#
#    (Your answer here)
