# %% [markdown]
# # Task 09c: BPA-Style Timed Practice
#
# **Objective:** Solve contest-format problems under time pressure.
#
# **Instructions:**
# - These problems mimic the BPA Python contest format
# - Each problem specifies input/output format clearly
# - Suggested time: ~8-10 minutes per problem

# %% [markdown]
# ## Problem 1: Count Character Types
#
# **Description:** Given a string, count the number of uppercase letters, lowercase letters, digits, and special characters.
#
# **Example:**
# ```
# Input: Hello123!
# Output:
# Uppercase: 1
# Lowercase: 4
# Digits: 3
# Special: 1
# ```

# %%
# Problem 1: Count Character Types
def problem1():
    # Your code here
    pass
