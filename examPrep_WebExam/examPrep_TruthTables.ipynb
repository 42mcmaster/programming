# %% [markdown]
# # Exam Prep: Boolean Logic & Truth Tables
#
# **Course:** CTE Programming | **School:** Medina County Career Center
# **Instructor:** Ryan McMaster
# **Standards:** ODE 5.3.1, 5.3.2, 5.3.3, 5.3.4
#
# ---
#
# ## How This Lesson Works
#
# 1. **Read** the markdown explanation of each concept
# 2. **Run** the example code cell — it's complete and ready to go
# 3. **Do** the short practice task in the empty cell that follows
#
# The cool part about doing truth tables in Python is that you can **check your answers** by running the code. Fill in what you *think* the answer is, then Python tells you if you're right.

# %% [markdown]
# ---
# ## Section 1: Boolean Values — True and False
#
# A **Boolean** is a data type with only two possible values: `True` or `False`. That's it — nothing else.
#
# You've already been using Booleans without thinking about it. Every time you write an `if` statement, the condition inside it evaluates to either `True` or `False`:
#
# ```python
# if age >= 16:    # age >= 16 is either True or False
# ```
#
# Comparisons like `>`, `<`, `==`, `!=`, `>=`, `<=` all produce Boolean values. You can also store Booleans directly in variables.

# %%
# EXAMPLE: Boolean values come from comparisons

# Each of these comparisons produces True or False
print(5 > 3)        # True — 5 is greater than 3
print(5 == 3)       # False — 5 does not equal 3 (== is "equals", = is assignment)
print(10 <= 10)     # True — 10 is less than or equal to 10
print("a" != "b")   # True — "a" is not equal to "b"

# You can store a Boolean in a variable, just like a number or string
is_raining = True
has_umbrella = False

# Check the type — it's 'bool'
print(type(is_raining))   # <class 'bool'>

# You can use Boolean variables directly in if statements
if is_raining:
    print("Grab an umbrella!")
else:
    print("Enjoy the sunshine!")

# %% [markdown]
# ### Practice Task 1
#
# Without running the code first, **predict** whether each comparison is `True` or `False`. Write your prediction as a comment, *then* uncomment the print to check.

# %%
# Write your prediction next to each, then uncomment the print to check

# Prediction: ____
# print(10 > 10)

# Prediction: ____
# print(10 >= 10)

# Prediction: ____
# print("hello" == "Hello")

# Prediction: ____
# print(7 != 7)

# Prediction: ____
# print(3 * 4 == 12)

# %% [markdown]
# ---
# ## Section 2: The AND Operator
#
# The `and` operator combines two Boolean values. The result is `True` **only when BOTH sides are True**. If either side is False, the whole thing is False.
#
# **Real-world example:** "I'll go to the beach if it's warm AND sunny." Both conditions must be true — warm but rainy? Nope. Sunny but cold? Nope. Only warm AND sunny works.
#
# ### The AND Truth Table
#
# A **truth table** shows every possible combination of inputs and what the output is:
#
# | A | B | A and B |
# |---|---|---------|
# | True | True | **True** |
# | True | False | **False** |
# | False | True | **False** |
# | False | False | **False** |
#
# **Memory trick:** AND is strict — it only says True when *everything* is True.

# %%
# EXAMPLE: The AND operator in action

# All four possible combinations
print(f"True  and True  = {True and True}")    # True — both are True
print(f"True  and False = {True and False}")   # False — second is False
print(f"False and True  = {False and True}")   # False — first is False
print(f"False and False = {False and False}")  # False — both are False

# A practical example: can you drive?
has_license = True
has_car = False

# You need BOTH a license AND a car to drive
can_drive = has_license and has_car   # True and False = False
print(f"\nHas license: {has_license}")
print(f"Has car: {has_car}")
print(f"Can drive? {can_drive}")       # False — missing the car

# %% [markdown]
# ### Practice Task 2
#
# Fill in your answers below (replace `None` with `True` or `False`), then run the cell. Python will tell you if you're right.

# %%
# Replace None with True or False — what do YOU think each one evaluates to?
my_answers = [
    None,   # True and True = ?
    None,   # True and False = ?
    None,   # False and True = ?
    None    # False and False = ?
]

# Python checks your answers
correct = [True and True, True and False, False and True, False and False]
labels = ["True  and True ", "True  and False", "False and True ", "False and False"]

for i in range(4):
    if my_answers[i] is None:
        print(f"  {labels[i]} = ??? (fill in your answer!)")
    elif my_answers[i] == correct[i]:
        print(f"  {labels[i]} = {correct[i]}  CORRECT")
    else:
        print(f"  {labels[i]} = you said {my_answers[i]}, answer is {correct[i]}  WRONG")

# %% [markdown]
# ---
# ## Section 3: The OR Operator
#
# The `or` operator combines two Boolean values. The result is `True` **when at least one side is True**. It's only False when *both* sides are False.
#
# **Real-world example:** "I'll be happy if I get pizza OR tacos." Pizza? Happy. Tacos? Happy. Both? Happy. Neither? Sad.
#
# ### The OR Truth Table
#
# | A | B | A or B |
# |---|---|--------|
# | True | True | **True** |
# | True | False | **True** |
# | False | True | **True** |
# | False | False | **False** |
#
# **Memory trick:** OR is generous — it says True as long as *at least one* input is True.

# %%
# EXAMPLE: The OR operator in action

# All four possible combinations
print(f"True  or True  = {True or True}")    # True — at least one is True
print(f"True  or False = {True or False}")   # True — first one is True
print(f"False or True  = {False or True}")   # True — second one is True
print(f"False or False = {False or False}")  # False — NEITHER is True

# A practical example: can you get into the movie?
is_18_or_older = False
has_parent_with_them = True

# You can get in if you're 18+ OR if you have a parent with you
can_enter = is_18_or_older or has_parent_with_them  # False or True = True
print(f"\nIs 18+: {is_18_or_older}")
print(f"Has parent: {has_parent_with_them}")
print(f"Can enter? {can_enter}")       # True — parent is with them

# %% [markdown]
# ### Practice Task 3
#
# Same drill — fill in your answers and check them.

# %%
# Replace None with True or False
my_answers = [
    None,   # True or True = ?
    None,   # True or False = ?
    None,   # False or True = ?
    None    # False or False = ?
]

correct = [True or True, True or False, False or True, False or False]
labels = ["True  or True ", "True  or False", "False or True ", "False or False"]

for i in range(4):
    if my_answers[i] is None:
        print(f"  {labels[i]} = ??? (fill in your answer!)")
    elif my_answers[i] == correct[i]:
        print(f"  {labels[i]} = {correct[i]}  CORRECT")
    else:
        print(f"  {labels[i]} = you said {my_answers[i]}, answer is {correct[i]}  WRONG")

# %% [markdown]
# ---
# ## Section 4: The NOT Operator
#
# The `not` operator is the simplest — it just **flips** the value. True becomes False. False becomes True.
#
# | A | not A |
# |---|-------|
# | True | **False** |
# | False | **True** |
#
# **Real-world example:** "If it's NOT raining, let's go outside." `not True` = False (it IS raining, so we stay in). `not False` = True (it's NOT raining, so we go out).

# %%
# EXAMPLE: The NOT operator flips True/False

print(f"not True  = {not True}")    # False — flipped from True
print(f"not False = {not False}")   # True — flipped from False

# Practical example
is_raining = True

# We want to go outside if it's NOT raining
if not is_raining:                   # not True = False, so this block is skipped
    print("Let's go outside!")
else:
    print("Better stay in.")

# Change the weather
is_raining = False
if not is_raining:                   # not False = True, so this block runs
    print("Now let's go outside!")

# %% [markdown]
# ### Practice Task 4
#
# For each line, predict the output, then uncomment to check:

# %%
# Prediction: ____
# print(not True)

# Prediction: ____
# print(not False)

# Prediction: ____ (hint: 5 > 3 is True, then not flips it)
# print(not (5 > 3))

# Prediction: ____ (hint: 10 == 20 is False, then not flips it)
# print(not (10 == 20))

# %% [markdown]
# ---
# ## Section 5: Order of Operations (Operator Precedence)
#
# When you combine `not`, `and`, and `or` in the same expression, Python evaluates them in a specific order — just like how multiplication happens before addition in math.
#
# **The order:**
# 1. `not` — evaluated **first** (like parentheses in math)
# 2. `and` — evaluated **second** (like multiplication)
# 3. `or` — evaluated **last** (like addition)
#
# **Tip:** When in doubt, use **parentheses** to make it explicit! Just like math, `(2 + 3) * 4` is clearer than `2 + 3 * 4`.

# %%
# EXAMPLE: Operator precedence — step by step

# Expression: not True or False and True
# Let's evaluate step by step using the order: not, then and, then or

# Step 1: Evaluate 'not' first
step1 = not True           # not True = False
print(f"Step 1: not True = {step1}")

# Step 2: Evaluate 'and' second 
step2 = False and True     # False and True = False
print(f"Step 2: False and True = {step2}")

# Step 3: Evaluate 'or' last
# We now have: False or False (step1 or step2)
step3 = step1 or step2     # False or False = False
print(f"Step 3: {step1} or {step2} = {step3}")

# Verify with Python doing it all at once
print(f"\nAll at once: not True or False and True = {not True or False and True}")

# PARENTHESES CHANGE EVERYTHING — just like in math
print(f"\n--- Parentheses change the result ---")
print(f"not True or False and True     = {not True or False and True}")       # False
print(f"not (True or False) and True   = {not (True or False) and True}")     # False
print(f"not (True or False and True)   = {not (True or False and True)}")     # False
print(f"(not True) or (False and True) = {(not True) or (False and True)}")   # False

# %% [markdown]
# ### Practice Task 5
#
# Evaluate each expression **by hand** first (write the steps as comments), then uncomment the print to check.

# %%
# 1. True and True or False
# Your steps:
#   Step 1 (and): True and True = ???
#   Step 2 (or):  ??? or False = ???
# My prediction: ____
# print(True and True or False)

# 2. not False and True
# Your steps:
#   Step 1 (not): not False = ???
#   Step 2 (and): ??? and True = ???
# My prediction: ____
# print(not False and True)

# 3. False or False or True
# Your steps:
#   Step 1 (or): False or False = ???
#   Step 2 (or): ??? or True = ???
# My prediction: ____
# print(False or False or True)

# 4. not (True and False)
# Your steps:
#   Step 1 (parentheses): True and False = ???
#   Step 2 (not): not ??? = ???
# My prediction: ____
# print(not (True and False))

# 5. True and not False or False
# Your steps:
#   Step 1 (not): not False = ???
#   Step 2 (and): True and ??? = ???
#   Step 3 (or):  ??? or False = ???
# My prediction: ____
# print(True and not False or False)

# %% [markdown]
# ---
# ## Section 6: Generating Truth Tables with Python
#
# Here's the fun part — Python can **generate an entire truth table** for any expression using nested for loops. This is a great way to verify your answers or explore new expressions.
#
# The trick: loop through every combination of True/False for each variable.

# %%
# EXAMPLE: Generate a truth table for A and (B or not C)
# With 3 variables, there are 2x2x2 = 8 possible combinations

# Print a header row
print(f"{'A':<8} {'B':<8} {'C':<8} {'A and (B or not C)':<20}")
print("-" * 44)   # a line of dashes to separate header from data

# Nested loops: one for each variable
# Each loop tries True first, then False
for A in [True, False]:              # outer loop: A is True, then False
    for B in [True, False]:          # middle loop: for each A, B is True then False
        for C in [True, False]:      # inner loop: for each A,B combo, C is True then False
            result = A and (B or not C)   # evaluate the expression
            print(f"{str(A):<8} {str(B):<8} {str(C):<8} {str(result):<20}")

# %% [markdown]
# ### Practice Task 6
#
# Generate a truth table for the expression `(A or B) and not (A and B)`.
#
# This is a famous Boolean expression called **XOR (exclusive or)**. It's `True` when A and B are *different*, and `False` when they're the *same*.
#
# Copy the structure from the example above and change:
# - The header text
# - The expression being evaluated
# - You only need 2 variables (A and B), so you only need 2 nested loops

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Section 7: Real-World Compound Conditions
#
# On the exam, you'll likely see Boolean logic applied to real scenarios — exactly the kind of `if` statements you write in actual programs. The key is translating an English description into a Python Boolean expression.

# %%
# EXAMPLE: Translating real scenarios into Boolean expressions

age = 16
has_permit = True
has_license = False
is_with_parent = True

# Scenario 1: "Can they drive?"
# Rule: You can drive if you have a license, OR if you have a permit AND are with a parent
can_drive = has_license or (has_permit and is_with_parent)
#           False      or (True       and True          )
#           False      or  True
#           True
print(f"Can drive? {can_drive}")         # True

# Scenario 2: "Must they take driver's ed?"
# Rule: Must take it if under 18 AND don't have a license yet
must_take_ed = age < 18 and not has_license
#              True     and not False
#              True     and True
#              True
print(f"Must take driver's ed? {must_take_ed}")  # True

# Scenario 3: "Can they drive alone?"
# Rule: Need a license AND be at least 16 AND not be with a parent
can_drive_alone = has_license and age >= 16 and not is_with_parent
#                 False      and ...  (False and anything = False — short circuits)
print(f"Can drive alone? {can_drive_alone}")     # False

# %% [markdown]
# ### Practice Task 7
#
# Given these variables, write the Boolean expression for each scenario, then print the result.
#
# ```python
# temperature = 72
# is_sunny = True
# is_weekend = False
# homework_done = True
# ```
#
# 1. **Can go to the beach?** — sunny AND temperature above 75
# 2. **Can play video games?** — homework is done AND (it's a weekend OR temperature is below 60)
# 3. **Should bring a jacket?** — it's NOT sunny OR temperature is below 65

# %%
# YOUR CODE HERE
temperature = 72
is_sunny = True
is_weekend = False
homework_done = True

# 1. Can go to the beach?

# 2. Can play video games?

# 3. Should bring a jacket?

# %% [markdown]
# ---
# ## Quick Reference
#
# | Operator | True When | Memory Trick |
# |----------|-----------|-------------|
# | `A and B` | Both are True | "Both must pass" |
# | `A or B` | At least one is True | "Either works" |
# | `not A` | A is False (flips it) | "Flip it" |
#
# **Order of operations:** `not` first, then `and`, then `or`. Use parentheses to be safe!
#
# **Exam tip:** When you see a compound condition, evaluate it step by step — do `not` first, then `and`, then `or`. Write out each step. Don't try to do it all in your head.
