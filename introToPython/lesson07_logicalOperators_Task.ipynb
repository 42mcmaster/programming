# %% [markdown]
# # Lesson 07 — Logical Operators (Task)
#
# **Name:**
# **Date:**
#
# Operators: `and`, `or`, `not` — always lowercase words, never symbols.

# %% [markdown]
# ## Exercise 1 — Predict, then run
#
# Write T or F next to each line before running.

# %%
# Pred: __
print(True and True)

# Pred: __
print(True and False)

# Pred: __
print(False or True)

# Pred: __
print(False or False)

# Pred: __
print(not True)

# Pred: __
print(not False)

# Pred: __
print((5 > 3) and (7 > 10))

# Pred: __
print((5 > 3) or (7 > 10))

# Pred: __
print(not (10 == 10))

# %% [markdown]
# ## Exercise 2 — Range check
#
# Ask the user for a number. Use `and` to check whether the number is between 10 and 20 **inclusive**. Print True or False.

# %%
# Your code here

# %% [markdown]
# ## Exercise 3 — Driving eligibility
#
# Ask the user their age and whether they have a license (`yes`/`no`). Using a single `if` with `and`, print `"You may drive."` only if BOTH conditions are met (age >= 16 and license is yes). Otherwise print `"You may not drive."`

# %%
# Your code here

# %% [markdown]
# ## Exercise 4 — Weekend check
#
# Ask the user for the name of a day (like `Saturday`). Using `or`, print `"Weekend!"` if they entered Saturday or Sunday, otherwise `"Weekday."`
#
# Use `.lower()` so the check is case-insensitive.

# %%
# Your code here

# %% [markdown]
# ## Exercise 5 — Traffic light
#
# Ask the user for a traffic light color (`red`, `yellow`, or `green`). Using `if`/`elif`/`else` with `==` comparisons, print:
#
# - `"Stop"` if red
# - `"Slow down"` if yellow
# - `"Go"` if green
# - `"Not a valid color"` if anything else
#
# Make it case-insensitive using `.lower()`.

# %%
# Your code here

# %% [markdown]
# ## Exercise 6 — Temperature + rain recommender
#
# Ask the user:
# - Temperature in °F (int)
# - Is it raining? (yes/no)
#
# Print a recommendation based on combining the two:
#
# - warm (≥70) AND not raining → `"Perfect — go outside!"`
# - warm AND raining → `"Warm but wet. Bring a jacket."`
# - cold (<70) AND raining → `"Cold and rainy. Stay in."`
# - cold AND not raining → `"Cold but dry. Bundle up."`

# %%
# Your code here

# %% [markdown]
# ## Exercise 7 — Fix the wrong operators
#
# Each line has a logical-operator mistake. Fix them in the cell below.
#
# ```python
# if age >= 16 && hasLicense:
#     ...
#
# if day == "Saturday" and day == "Sunday":
#     ...
#
# if color == "red" or "blue":
#     ...
#
# if !isRaining:
#     ...
# ```

# %%
# Your corrected code here (doesn't need to run with real variables — just show the fixed form)

# %% [markdown]
# ## When you're done
#
# Save, commit `lesson07 complete`, raise your hand.
