# %% [markdown]
# # Lesson 06 — if / elif / else (Task)
#
# **Name:**
# **Date:**
#
# Remember: `if`, `elif`, and `else` all need a colon at the end of the line, and the code underneath must be **indented 4 spaces**.

# %% [markdown]
# ## Exercise 1 — Adult or minor
#
# Ask the user their age. Print `"You are an adult."` if they're 18 or older, otherwise print `"You are a minor."`

# %%
# Your code here

# %% [markdown]
# ## Exercise 2 — Even or odd
#
# Ask the user for an integer. Use `% 2` to decide whether it's even or odd, and print which it is.

# %%
# Your code here

# %% [markdown]
# ## Exercise 3 — Letter grade
#
# Ask for a test score (0-100). Print the letter grade using this scale:
#
# - 90+ → A
# - 80-89 → B
# - 70-79 → C
# - 60-69 → D
# - below 60 → F
#
# Use one `if` / `elif` / `elif` / `elif` / `else` ladder.

# %%
# Your code here

# %% [markdown]
# ## Exercise 4 — Number classifier
#
# Ask the user for a number. Print whether it's `"positive"`, `"negative"`, or `"zero"`.

# %%
# Your code here

# %% [markdown]
# ## Exercise 5 — Day of week from number
#
# Ask the user for a number 1–7. Print the name of that day (1=Monday, 7=Sunday). If they enter something outside 1–7, print `"Not a valid day."`

# %%
# Your code here

# %% [markdown]
# ## Exercise 6 — Ticket price
#
# Movie ticket pricing:
# - Age 12 or under: $8
# - Age 13 to 59: $12
# - Age 60 and over: $9
#
# Ask the user their age and print their ticket price using an f-string.

# %%
# Your code here

# %% [markdown]
# ## Exercise 7 — Nested if (bonus)
#
# Ask for age **and** whether the user has a driver's license (yes/no). Use a nested `if` to print one of three messages:
#
# - If age >= 16 AND has license: `"You can drive."`
# - If age >= 16 AND no license: `"Old enough, but no license yet."`
# - If age < 16: `"Too young to drive."`
#
# (We'll learn `and`/`or` next lesson to make this cleaner, but for now solve it with a nested `if`.)

# %%
# Your code here

# %% [markdown]
# ## When you're done
#
# Save, commit `lesson06 complete`, raise your hand.
