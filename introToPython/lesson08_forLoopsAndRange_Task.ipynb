# %% [markdown]
# # Lesson 08 — `for` Loops and `range()` (Task)
#
# **Name:**
# **Date:**
#
# Three forms of `range()`:
# - `range(n)` → 0 to n-1
# - `range(a, b)` → a to b-1
# - `range(a, b, step)` → a to b-1 jumping by step

# %% [markdown]
# ## Exercise 1 — Print 1 through 10
#
# Write a `for` loop that prints the numbers 1 through 10, each on its own line. Be careful about the range endpoints.

# %%
# Your code here

# %% [markdown]
# ## Exercise 2 — Countdown
#
# Use a `for` loop with a negative step to count down from 10 to 1. After the loop, print `"Blast off!"`.

# %%
# Your code here

# %% [markdown]
# ## Exercise 3 — Even numbers 0 to 20
#
# Use a `for` loop with a step of 2 to print all even numbers from 0 through 20, inclusive.

# %%
# Your code here

# %% [markdown]
# ## Exercise 4 — Sum of 1 through N (accumulator)
#
# Ask the user for a positive integer N. Use the accumulator pattern to compute `1 + 2 + 3 + ... + N` and print the result.
#
# Example:
#
# ```
# Enter N: 5
# The sum is 15
# ```

# %%
# Your code here

# %% [markdown]
# ## Exercise 5 — Multiplication table
#
# Ask the user for a number. Use a `for` loop to print its multiplication table from 1 to 12, using an f-string.
#
# Example for 3:
#
# ```
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# ...
# 3 x 12 = 36
# ```

# %%
# Your code here

# %% [markdown]
# ## Exercise 6 — Count a letter in a word
#
# Ask the user for a word. Loop over it character by character and **count** how many times the letter `e` appears. Use the accumulator pattern (start at 0, add 1 each match). Print the count.

# %%
# Your code here

# %% [markdown]
# ## Exercise 7 — Average of N numbers
#
# Ask the user how many numbers they want to enter. Use a `for` loop to collect that many numbers (as floats), keeping a running total with the accumulator pattern. After the loop, print the **average** rounded to 2 decimals.
#
# Example:
#
# ```
# How many numbers? 3
# Number 1: 10
# Number 2: 20
# Number 3: 30
# Average: 20.00
# ```

# %%
# Your code here

# %% [markdown]
# ## When you're done
#
# Save, commit `lesson08 complete`, raise your hand.
