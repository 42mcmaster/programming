# %% [markdown]
# # Lesson 04 — Arithmetic and f-strings (Task)
#
# **Name:**
# **Date:**
#
# Operators you should know by heart: `+  -  *  /  //  %  **`
# f-string syntax: `f"... {variable} ..."`

# %% [markdown]
# ## Exercise 1 — Predict, then run
#
# Write a comment predicting each output. Then run and verify.

# %%
# Prediction 1: _____
print(7 + 3 * 2)

# Prediction 2: _____
print((7 + 3) * 2)

# Prediction 3: _____
print(20 / 6)

# Prediction 4: _____
print(20 // 6)

# Prediction 5: _____
print(20 % 6)

# Prediction 6: _____
print(3 ** 4)

# %% [markdown]
# ## Exercise 2 — Rectangle area and perimeter
#
# Ask the user for the **length** and **width** of a rectangle (as floats). Calculate the area and the perimeter. Print both using f-strings, rounded to 2 decimals.
#
# Example:
#
# ```
# Length: 5
# Width: 3
# Area: 15.00
# Perimeter: 16.00
# ```

# %%
# Your code here

# %% [markdown]
# ## Exercise 3 — Change maker
#
# Ask the user for a number of total cents (as `int`, like `287`). Use `//` and `%` to break it into quarters, dimes, nickels, and pennies. Print the result.
#
# Example:
#
# ```
# Total cents: 287
# Quarters: 11
# Dimes: 1
# Nickels: 0
# Pennies: 2
# ```
#
# Hints:
# - `quarters = cents // 25`
# - `remaining = cents % 25`
# - Then break `remaining` into dimes, nickels, pennies the same way.

# %%
# Your code here

# %% [markdown]
# ## Exercise 4 — Odd or even (no if statements yet)
#
# Ask the user for a number. Use `%` to print the remainder when dividing by 2. (If the remainder is 0, the number is even.) For now, just print the remainder — we'll make it smarter next lesson.
#
# Example:
#
# ```
# Number: 7
# 7 divided by 2 has remainder 1.
# ```

# %%
# Your code here

# %% [markdown]
# ## Exercise 5 — Rewrite with f-strings
#
# Below is an old-style `print` using `+` and `str()`. Rewrite it in the cell underneath using an f-string.
#
# ```python
# firstName = "Alex"
# score = 88
# print("Student " + firstName + " scored " + str(score) + " out of 100.")
# ```

# %%
# Your f-string version here

# %% [markdown]
# ## Exercise 6 — Tip calculator (with formatting)
#
# Ask for the price of a meal. Calculate a 15%, 18%, and 20% tip. Print each one on its own line, each dollar amount with **2 decimal places**.
#
# Example:
#
# ```
# Meal price: 25.00
# 15% tip: $3.75
# 18% tip: $4.50
# 20% tip: $5.00
# ```

# %%
# Your code here

# %% [markdown]
# ## Exercise 7 — Age in different units
#
# Ask the user their age in years. Print their age in months, weeks, and days (approximate). Use f-strings for all output.
#
# Use these conversions:
# - months: `age * 12`
# - weeks: `age * 52`
# - days: `age * 365`
#
# Example:
#
# ```
# Age in years? 17
# You are approximately:
#   204 months old
#   884 weeks old
#   6205 days old
# ```

# %%
# Your code here

# %% [markdown]
# ## When you're done
#
# Save, commit `lesson04 complete`, raise your hand.
