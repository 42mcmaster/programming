# %% [markdown]
# # Lesson 05 — Comparison Operators (Task)
#
# **Name:**
# **Date:**
#
# Operators: `==  !=  <  >  <=  >=`
# Every comparison returns `True` or `False`.

# %% [markdown]
# ## Exercise 1 — Predict, then run
#
# Before running the cell, write a prediction (`True` or `False`) next to each line. Then run it.

# %%
# Pred: __
print(10 == 10)

# Pred: __
print(10 == 10.0)

# Pred: __
print(10 != 11)

# Pred: __
print("cat" == "CAT")

# Pred: __
print(5 > 5)

# Pred: __
print(5 >= 5)

# Pred: __
print(7 < 3)

# Pred: __
print("apple" < "banana")

# %% [markdown]
# ## Exercise 2 — Fix = vs ==
#
# Each line below has a mistake. Copy it into the empty cell and fix it so it runs.
#
# ```python
# age = 17
# print(age = 17)
# print(age == 18)
# ```

# %%
# Your fixed code here

# %% [markdown]
# ## Exercise 3 — Temperature booleans
#
# Ask the user for a temperature in °F. Store **four** booleans:
#
# - `isFreezing` — True if the temperature is at or below 32
# - `isCold` — True if below 50
# - `isWarm` — True if at or above 70
# - `isHot` — True if at or above 90
#
# Print each one on its own line using an f-string.

# %%
# Your code here

# %% [markdown]
# ## Exercise 4 — Password match (case-sensitive)
#
# The secret password is `swordfish`. Ask the user to enter the password. Print a bool showing whether they got it right. Test it with the right password, with wrong passwords, and with `SWORDFISH` (should be False).

# %%
# Your code here

# %% [markdown]
# ## Exercise 5 — Password match (case-insensitive)
#
# Same as Exercise 4 but use `.lower()` so that `SWORDFISH`, `Swordfish`, and `swordfish` all match.

# %%
# Your code here

# %% [markdown]
# ## Exercise 6 — Voting age
#
# Ask the user their age. Store a bool called `canVote` that is True if age is 18 or higher. Print the bool.
#
# Then print another bool called `isSenior` that is True if age is 65 or higher.

# %%
# Your code here

# %% [markdown]
# ## Exercise 7 — Range check (chained comparison)
#
# Ask the user for a number. Store a bool called `inRange` that is True if the number is between 10 and 20, **inclusive**. You can use the Python chain `10 <= n <= 20`.

# %%
# Your code here

# %% [markdown]
# ## When you're done
#
# Save, commit `lesson05 complete`, raise your hand.
