# %% [markdown]
# # Lesson 02 — Variables and Data Types (Task)
#
# **Name:**
# **Date:**
#
# The four basic types we're using today: **int**, **float**, **str**, **bool**.

# %% [markdown]
# ## Exercise 1 — Create four variables
#
# Create one variable of each of the four basic types:
#
# - an `int` called `myAge`
# - a `float` called `myHeightInFeet`
# - a `str` called `myName`
# - a `bool` called `likesPizza`
#
# Then print each one on its own line.

# %%
# Your code here

# %% [markdown]
# ## Exercise 2 — Check the types
#
# Using the variables from Exercise 1, call `type()` on each one and print the result. You should see four different types.

# %%
# Your code here

# %% [markdown]
# ## Exercise 3 — Reassignment
#
# Create a variable called `score` and set it to `50`. Print it. Then change `score` to `75`. Print it again. You should see both values in order.

# %%
# Your code here

# %% [markdown]
# ## Exercise 4 — Spot the type
#
# For each of these values, write a short comment saying whether it's an `int`, `float`, `str`, or `bool`. Then uncomment the `print(type(...))` line to confirm.
#
# ```python
# 42
# "42"
# 3.14
# True
# "True"
# 0
# -17.5
# "hello world"
# ```

# %%
# Guess the type, then check with type().
# Example:
# 42 is an int
# print(type(42))

# 42 is ___
print(type(42))

# "42" is ___
print(type("42"))

# 3.14 is ___
print(type(3.14))

# True is ___
print(type(True))

# "True" is ___
print(type("True"))

# 0 is ___
print(type(0))

# -17.5 is ___
print(type(-17.5))

# "hello world" is ___
print(type("hello world"))

# %% [markdown]
# ## Exercise 5 — Fix the variable names
#
# Each of these variable names has a problem. In the cell below, rewrite each one using a valid, descriptive name, and assign it a reasonable value.
#
# ```python
# 2age = 17
# first name = "Alex"
# x = "coffee"
# if = True
# grade-level = 12
# ```

# %%
# Your corrected variable names here (plus reasonable values).

# %% [markdown]
# ## Exercise 6 — Profile card
#
# Create **five** variables describing yourself (pick whatever fits — favorite movie, pet's name, height, whether you're a senior, etc.). Use at least one of each type: `int`, `float`, `str`, `bool`.
#
# Then use `print()` statements to display a small profile card, like:
#
# ```
# Name: Ryan
# Age: 17
# Height (ft): 5.9
# Favorite color: green
# Has pet: True
# ```

# %%
# Your code here

# %% [markdown]
# ## Exercise 7 — Predict, then run
#
# Before you run the cell below, write a comment predicting what will print. Then run it and see if you were right.

# %%
# Prediction: I think the output will be _____________________________________

points = 10
points = 25
points = 100
print("Final points:", points)

# %% [markdown]
# ## When you're done
#
# 1. Save the notebook.
# 2. Commit to the repo with a message like `lesson02 complete`.
# 3. Raise your hand for a check-off.
