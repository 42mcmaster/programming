# %% [markdown]
# # Lesson 10 — Functions and Docstrings (Task)
#
# **Name:**
# **Date:**
#
# Every function in this notebook must have:
# 1. A descriptive name.
# 2. A **docstring** in triple quotes right after `def`.
# 3. A `return` statement (unless the function's whole job is to print).

# %% [markdown]
# ## Exercise 1 — `greet(name)`
#
# Write a function `greet(name)` that **prints** `Hello, <name>!`. Call it three times with three different names.

# %%
# Your code here

# %% [markdown]
# ## Exercise 2 — `rectangleArea(length, width)`
#
# Write a function `rectangleArea(length, width)` that **returns** the area. Call it on a few rectangles and print the results.

# %%
# Your code here

# %% [markdown]
# ## Exercise 3 — `circleArea(radius)`
#
# Write `circleArea(radius)` that returns the area of a circle (`π × r²`). Use `3.14159` for pi (we'll pull from the `math` module in future lessons). Test with a couple of values.
#
# Area of a circle with radius 5: should be about 78.54.

# %%
# Your code here

# %% [markdown]
# ## Exercise 4 — `fahrenheitToCelsius(f)`
#
# Write `fahrenheitToCelsius(f)` that returns the Celsius equivalent of a Fahrenheit temperature.
#
# Formula: `(f - 32) * 5/9`
#
# Test with 32°F (should be 0), 212°F (should be 100), 72°F (~22.2).

# %%
# Your code here

# %% [markdown]
# ## Exercise 5 — `getLetterGrade(score)`
#
# Write `getLetterGrade(score)` that returns the letter grade A/B/C/D/F based on a numeric score (use the scale from Lesson 06). Then use the function in a short loop that prints the grade for a few scores:
#
# ```python
# for s in [95, 82, 71, 63, 40]:
#     print(f"{s} -> {getLetterGrade(s)}")
# ```

# %%
# Your code here

# %% [markdown]
# ## Exercise 6 — `priceWithTax(price, rate=0.075)`
#
# Write `priceWithTax(price, rate=0.075)` that returns the price plus tax. Rate defaults to 7.5%. Test it with a few calls:
#
# - `priceWithTax(100)` — uses default rate
# - `priceWithTax(100, 0.06)` — uses 6%
# - `priceWithTax(50, 0.10)` — uses 10%

# %%
# Your code here

# %% [markdown]
# ## Exercise 7 — Mini BMI calculator (combines functions)
#
# Write **two** functions:
#
# 1. `calculateBMI(weightLbs, heightInches)` — returns BMI using `(weight / (height ** 2)) * 703`.
# 2. `bmiCategory(bmi)` — returns one of `"Underweight"`, `"Normal"`, `"Overweight"`, `"Obese"` using the scale:
#    `< 18.5` → Underweight, `< 25` → Normal, `< 30` → Overweight, `>= 30` → Obese.
#
# Then ask the user for weight and height, call both functions, and print the BMI + category using an f-string.

# %%
# Your code here

# %% [markdown]
# ## When you're done
#
# Save, commit `lesson10 complete`, raise your hand.
#
# Congratulations — you've now covered the core of Python: output, variables, types, input, arithmetic, conditionals, loops, and functions. Everything else we do builds on this foundation.
