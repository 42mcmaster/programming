# %% [markdown]
# # Lesson 09 — `while` Loops, `break`, `continue` (Task)
#
# **Name:**
# **Date:**
#
# Heads up: **if you write an infinite loop**, click the ⬛ stop/interrupt button in the notebook toolbar to kill it.

# %% [markdown]
# ## Exercise 1 — Count to 10 with a while loop
#
# Use a `while` loop to print the numbers 1 through 10. Don't forget to update your counter inside the loop.

# %%
# Your code here

# %% [markdown]
# ## Exercise 2 — Countdown with a while loop
#
# Use a `while` loop to count down from 10 to 1. After the loop, print `"Blast off!"`

# %%
# Your code here

# %% [markdown]
# ## Exercise 3 — Input validation: positive integer
#
# Use the `while True` + `break` pattern to keep asking the user for input until they enter a positive integer (use `.isdigit()` and `int(...) > 0`). Once you have a valid value, print `"You entered: <value>"`.
#
# Test it by typing: `hello`, `-5`, `0`, `abc`, and finally a positive number.

# %%
# Your code here

# %% [markdown]
# ## Exercise 4 — Input validation: menu choice
#
# Ask the user to choose A, B, or C. Keep asking until they enter one of those three (accept any capitalization). Then print their choice.
#
# Hint: use `.upper()` and `choice in ("A", "B", "C")`.

# %%
# Your code here

# %% [markdown]
# ## Exercise 5 — Sum-until-zero (sentinel loop)
#
# Keep asking the user for numbers (`float`). When they enter `0`, stop and print the sum of everything they entered.
#
# Example:
#
# ```
# Number (0 to stop): 5
# Number (0 to stop): 3.5
# Number (0 to stop): 1.5
# Number (0 to stop): 0
# Total: 10.0
# ```

# %%
# Your code here

# %% [markdown]
# ## Exercise 6 — Skip the multiples of 3
#
# Use a `for` loop from 1 to 20 (inclusive). Use `continue` to skip any number that's a multiple of 3 (`i % 3 == 0`). Print everything else.

# %%
# Your code here

# %% [markdown]
# ## Exercise 7 — Password attempts
#
# The correct password is `openSesame`. Give the user up to **3 tries** to guess it.
#
# - If they get it right, print `"Access granted."` and break out of the loop.
# - If they use all 3 tries without success, print `"Account locked."`
#
# Hint: you can combine a counter with `while` or use a `for i in range(3)` + `break`.

# %%
# Your code here

# %% [markdown]
# ## When you're done
#
# Save, commit `lesson09 complete`, raise your hand.
