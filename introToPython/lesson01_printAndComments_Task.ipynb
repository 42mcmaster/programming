# %% [markdown]
# # Lesson 01 — Printing and Comments (Task)
#
# **Name:**
# **Date:**
#
# Work through each exercise. Run each cell with **Shift+Enter**. When you're done, save the notebook and commit it to the repo.
#
# Every exercise has a comment block above it telling you what to do. Follow along.

# %% [markdown]
# ## Exercise 1 — Hello, your name
#
# In the cell below, use `print()` to print a greeting that includes **your first name**.
#
# Example output: `Hello, I'm Ryan.`

# %%
# Your code here

# %% [markdown]
# ## Exercise 2 — Three separate print statements
#
# Write three `print()` statements, one per line, that print:
#
# 1. Your favorite food
# 2. Your favorite number (no quotes — it's a number)
# 3. Your favorite color

# %%
# Your code here

# %% [markdown]
# ## Exercise 3 — Print with multiple arguments
#
# Use a single `print()` call with multiple arguments separated by commas to print:
#
# `I am 17 years old and I live in Ohio.`
#
# Remember: a comma between arguments puts a space between them automatically.

# %%
# Your code here

# %% [markdown]
# ## Exercise 4 — Comments
#
# In the cell below:
#
# 1. Write a header comment block (4 lines) with: `Program:`, `Author:`, `Date:`, and `Purpose:`.
# 2. Below the header, write **one** `print()` statement that prints any message you want.
# 3. Add an end-of-line comment on that `print` line that explains what it does.

# %%
# Your code here

# %% [markdown]
# ## Exercise 5 — Fix the broken code
#
# The cell below has **four** mistakes. Copy it into the empty cell underneath and fix all four. Run your corrected version to make sure it works.
#
# ```python
# Print(Hello)
# print('I'm learning Python)
# PRINT("This is fun")
# print "Goodbye"
# ```

# %%
# Your corrected code here

# %% [markdown]
# ## Exercise 6 — Blank line spacer
#
# Use `print()` calls to produce exactly this output:
#
# ```
# Top line
#
# Middle line
#
# Bottom line
# ```
#
# Hint: `print()` with nothing in the parentheses prints a blank line.

# %%
# Your code here

# %% [markdown]
# ## Exercise 7 — Business card
#
# Write a short program that prints a fake business card. Use `print()` calls to produce something like:
#
# ```
# ----------------------
#   Ryan McMaster
#   Medina CCC — SE1
#   ryan@example.com
# ----------------------
# ```
#
# Make it **your** card — use your name and a made-up email. Add a comment at the top explaining what the program does.

# %%
# Your code here

# %% [markdown]
# ## When you're done
#
# 1. Save the notebook (**Ctrl+S**).
# 2. Commit to the repo with a message like `lesson01 complete`.
# 3. Raise your hand so I can check it off.
