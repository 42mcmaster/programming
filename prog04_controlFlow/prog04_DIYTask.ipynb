# %% [markdown]
# # Lesson 04: DIY Task — Number Guessing Game
#
# **Instructor:** Ryan McMaster
# **Course:** Programming, Medina County Career Center
#
# Create a complete program from scratch using conditionals, loops, and all the patterns you've learned.

# %% [markdown]
# ---
# ## Project: Number Guessing Game
#
# Create a complete number guessing game where:
#
# 1. The computer picks a random number between 1 and 100
# 2. The player guesses the number
# 3. The program gives hints: "Too high" or "Too low"
# 4. Count the number of attempts
# 5. When the player guesses correctly, show the number of attempts and ask if they want to play again
# 6. Keep playing until the user says no
#
# ### Features Required:
# - Import the `random` module to generate random numbers
# - Use conditionals (if/elif/else) for hints
# - Use loops (while, for) for game flow
# - Use an accumulator pattern to count attempts
# - Use input validation to ensure valid guesses
# - Use a sentinel loop to allow multiple games
#
# ### Sample Output:
# ```
# Welcome to the Number Guessing Game!
# I'm thinking of a number between 1 and 100.
#
# Guess the number: 50
# Too high! Try again.
# Guess the number: 25
# Too low! Try again.
# Guess the number: 37
# Correct! You got it in 3 attempts!
#
# Do you want to play again? (yes/no): no
# Thanks for playing!
# ```

# %% [markdown]
# ### Step 1: Import random and understand random.randint()

# %%
# This generates a random number between 1 and 100 (inclusive)
import random

secretNumber = random.randint(1, 100)
print(f"Secret number for testing: {secretNumber}")

# %% [markdown]
# ### Step 2: Build the basic guessing logic

# %% [markdown]
# Your code here:
#
# 1. Generate a random number
# 2. Create a loop that:
#    - Asks the user to guess
#    - Validates the input (must be a number between 1 and 100)
#    - Gives feedback (too high, too low, or correct)
#    - Counts attempts
#    - Exits when guessed correctly

# %%
# Your code here — single game

# %% [markdown]
# ### Step 3: Add replay functionality

# %% [markdown]
# Wrap your game logic in another loop so the user can play multiple times.
#
# Use a sentinel loop (while True) that breaks when the user doesn't want to play again.

# %%
# Your code here — complete game with replay
import random

# %% [markdown]
# ---
# ## Rubric
#
# - **Functionality (40%):**
#   - Game generates a random number (5 pts)
#   - Player can guess and gets feedback (10 pts)
#   - Correct guess is detected and game ends (10 pts)
#   - Player can play multiple games (10 pts)
#   - Program exits when requested (5 pts)
#
# - **Code Quality (30%):**
#   - Input validation loop (10 pts)
#   - Attempt counter working correctly (10 pts)
#   - Clear, readable code with comments (10 pts)
#
# - **Control Flow (30%):**
#   - Proper use of if/elif/else (10 pts)
#   - Proper use of while loops (10 pts)
#   - break and loop control statements used correctly (10 pts)
