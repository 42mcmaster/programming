# %% [markdown]
# # prog03c Task — Writing Real Programs
#
# **Medina County Career Center**
# **Instructor: Ryan McMaster**
#
# In this task, you'll write complete programs following good structure:
# 1. Comments
# 2. Constants (if needed)
# 3. Input
# 4. Processing
# 5. Output
#
# Start simple, then add complexity.

# %% [markdown]
# ## Program 1: Temperature Converter
#
# Write a program that:
# 1. Asks the user for a temperature in Celsius
# 2. Converts it to Fahrenheit using: F = (C × 9/5) + 32
# 3. Prints the result in a formatted way
#
# Example:
# ```
# Enter temperature in Celsius: 25
# 25°C = 77°F
# ```

# %%
# Your code here

# %% [markdown]
# ## Program 2: Tip Calculator
#
# Write a program that:
# 1. Asks for the bill amount
# 2. Asks for the tip percentage (or use a constant like 18%)
# 3. Calculates the tip amount and total
# 4. Prints both with 2 decimal places
#
# Example:
# ```
# Enter bill amount: $50.00
# Enter tip percentage: 18
# Bill: $50.00
# Tip: $9.00
# Total: $59.00
# ```

# %%
# Your code here

# %% [markdown]
# ## Program 3: Simple Payroll Calculator
#
# Write a program that:
# 1. Asks for hourly wage
# 2. Asks for hours worked
# 3. Calculates gross pay
# 4. Calculates tax (assume 15%)
# 5. Calculates net pay
# 6. Prints a summary
#
# Example:
# ```
# Enter hourly wage: $15.00
# Enter hours worked: 40
# ---
# Gross Pay: $600.00
# Tax (15%): $90.00
# Net Pay: $510.00
# ```

# %%
# Your code here

# %% [markdown]
# ## Program 4: Area of a Rectangle
#
# Write a program that:
# 1. Asks for the length of a rectangle
# 2. Asks for the width
# 3. Calculates the area (length × width) and perimeter (2 × (length + width))
# 4. Prints both
#
# Example:
# ```
# Enter length: 10
# Enter width: 5
# Area: 50
# Perimeter: 30
# ```

# %%
# Your code here

# %% [markdown]
# ## Program 5: GPA Calculator
#
# Write a program that:
# 1. Asks for the name of a student
# 2. Asks for three test scores
# 3. Calculates the average
# 4. Prints a summary
#
# Example:
# ```
# Enter student name: Alice
# Enter test 1 score: 85
# Enter test 2 score: 92
# Enter test 3 score: 88
# ---
# Student: Alice
# Average: 88.33
# ```

# %%
# Your code here

# %% [markdown]
# ## Challenge: Currency Converter
#
# Write a program that:
# 1. Asks for an amount in US dollars
# 2. Uses a constant conversion rate (e.g., 1 USD = 0.92 EUR)
# 3. Converts and prints the result
#
# Example:
# ```
# Enter amount in USD: 100
# 100 USD = 92.00 EUR
# ```
#
# **Hint:** Use a constant for the exchange rate at the top of your code.

# %%
# Your code here
