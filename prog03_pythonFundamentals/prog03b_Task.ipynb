# %% [markdown]
# # prog03b Task — Variables, Types, and I/O
#
# **Medina County Career Center**
# **Instructor: Ryan McMaster**
#
# In this task, you'll practice:
# - Creating variables with different types
# - Using `type()` to verify types
# - Getting input from the user
# - Converting types
# - Working with arithmetic operators

# %% [markdown]
# ## Exercise 1: Create Variables and Check Types
#
# Create the following variables and use `type()` to verify each one:
# - An integer named `studentCount`
# - A float named `classAverage`
# - A string named `schoolName`
# - A boolean named `isAccredited`

# %%
# Your code here

# %% [markdown]
# ## Exercise 2: Input and Type Conversion
#
# Ask the user for their favorite number (as a string), convert it to an integer, then print it doubled.

# %%
# Your code here

# %% [markdown]
# ## Exercise 3: Converting a String to a Float
#
# Ask the user for the price of an item. Convert it to a float and calculate the cost with 10% tax added.

# %%
# Your code here

# %% [markdown]
# ## Exercise 4: Division Differences
#
# Create two variables: `a = 10` and `b = 3`.
# Calculate:
# - `a / b` (regular division)
# - `a // b` (integer division)
# - `a % b` (modulo)
#
# Print all three results and use `type()` to show that `/` returns a float.

# %%
# Your code here

# %% [markdown]
# ## Exercise 5: Order of Operations
#
# Calculate: `2 + 3 * 4` and `(2 + 3) * 4` in Python. Are they different? Print both results.

# %%
# Your code here

# %% [markdown]
# ## Exercise 6: String to Number Conversion
#
# Get two numbers from the user (as strings), convert them to integers, and print their sum, difference, and product.

# %%
# Your code here

# %% [markdown]
# ## Exercise 7: Combining Input and Arithmetic
#
# Ask the user for:
# - Their hourly wage (float)
# - Hours worked this week (integer)
#
# Calculate and print their gross pay.

# %%
# Your code here

# %% [markdown]
# ## Exercise 8: Type Checking Challenge
#
# Create a variable `result` that equals `5 + 2.5`. What type is it? Use `type()` to check.

# %%
# Your code here

# %% [markdown]
# ## Exercise 9: String Conversion
#
# Create an integer variable with your age. Use `str()` to convert it to a string and concatenate it into a sentence using an f-string.

# %%
# Your code here

# %% [markdown]
# ## Exercise 10: Convert String to Boolean
#
# In Python, any non-empty string is considered `True`, and an empty string is `False`.
#
# Create three strings:
# - A non-empty string
# - An empty string
# - The string "False"
#
# Use `bool()` on each and observe the results.

# %%
# Your code here
