# %% [markdown]
# # prog03 DIY Task — Personal Info Card
#
# **Medina County Career Center**
# **Instructor: Ryan McMaster**
#
# ## Challenge: Create a "Personal Info Card" Program
#
# Write a program that collects information about yourself and displays a formatted "card."
#
# ### Requirements:
#
# 1. **Inputs** (get from user):
#    - Full name (string)
#    - Age (integer)
#    - Favorite hobby (string)
#    - Number of pets (integer)
#    - Average grade in this class (float)
#
# 2. **Calculations**:
#    - Calculate the year you'll graduate (current year + 4 - age)
#    - Calculate your pet to person ratio (pets per year of age)
#    - Calculate a "grade percentage" (grade as a percentage, e.g., 3.8 GPA = 95%)
#
# 3. **Output** (display as a formatted card):
#    ```
#    ========================================
#    PERSONAL INFO CARD
#    ========================================
#    Name: [Name]
#    Age: [Age]
#    Favorite Hobby: [Hobby]
#    Number of Pets: [Pets]
#
#    Current Average: [Grade]
#    Grade Percentage: [Percent]%
#
#    Expected Graduation Year: [Year]
#    Pets per Year of Age: [Ratio]
#    ========================================
#    ```
#
# ### Tips:
# - Use f-strings for all output
# - Use `:.2f` to format decimals to 2 places
# - Use `int()` to convert floats to integers where needed (like year)
# - Consider using a constant for the current year
#
# ### Example Output:
# ```
# ========================================
# PERSONAL INFO CARD
# ========================================
# Name: Sarah Johnson
# Age: 16
# Favorite Hobby: Soccer
# Number of Pets: 2
#
# Current Average: 3.8
# Grade Percentage: 95.00%
#
# Expected Graduation Year: 2026
# Pets per Year of Age: 0.13
# ========================================
# ```

# %%
# Your complete program here

# %% [markdown]
# ## Reflection Questions
#
# After completing your program, answer these:
#
# 1. What data types did you use, and why?
# 2. How did f-strings help make your output cleaner?
# 3. If you were writing this in C instead of Python, what would be more difficult?

# %% [markdown]
# Write your reflection here:
#
# 1.
#
# 2.
#
# 3.
