# %% [markdown]
# # prog05_DIYTask: Dice Game
# **Course**: Programming (CTE) | **Instructor**: Ryan McMaster

# %% [markdown]
# ## Game Rules
# 1. Player rolls two dice
# 2. Sum of 7 or 11: Win!
# 3. Sum of 2, 3, or 12: Lose!
# 4. Any other sum: becomes your point
# 5. Keep rolling until you roll your point (win) or roll a 7 (lose)

# %% [markdown]
# ## Part 1: Roll Dice Function

# %%
# Write rollDice() - rolls two dice, returns sum
# Your code here

# Test
for i in range(5):
    print(f"Roll {i+1}: {rollDice()}")

# %% [markdown]
# ## Part 2: Check First Roll Function

# %%
# Write checkFirstRoll(roll) - returns "win", "lose", or the point number
# Your code here

# Test
print(checkFirstRoll(7))
print(checkFirstRoll(2))
print(checkFirstRoll(6))

# %% [markdown]
# ## Part 3: Check Point Roll Function

# %%
# Write checkPointRoll(roll, point) - returns "win", "lose", or "continue"
# Your code here

# Test
print(checkPointRoll(6, 6))
print(checkPointRoll(7, 6))
print(checkPointRoll(4, 6))

# %% [markdown]
# ## Part 4: Play One Game Function

# %%
# Write playGame() - orchestrates the entire game
# Your code here

# playGame()

# %% [markdown]
# ## Part 5: Main Program

# %%
# Main program
# play_again = "yes"
# while play_again.lower() == "yes":
#     playGame()
#     play_again = input("Play again? (yes/no): ")
# print("Thanks for playing!")
