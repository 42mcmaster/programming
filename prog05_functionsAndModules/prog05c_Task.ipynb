# %% [markdown]
# # prog05c_Task: Multi-Function Program — Simple Calculator
# **Course**: Programming (CTE) | **Instructor**: Ryan McMaster
# **Medina County Career Center**
#
# Build a calculator program using multiple functions. This demonstrates code organization and functions calling functions.

# %% [markdown]
# ## Part 1: Create Individual Operation Functions
#
# Write four functions for basic operations. Each should:
# - Take two parameters (operands)
# - Return the result
# - Include a docstring

# %%
# Function 1: add
# Your code here

# Function 2: subtract
# Your code here

# Function 3: multiply
# Your code here

# Function 4: divide
# Your code here
# Hint: Check for division by zero!

# Test the functions
print(f"add(10, 5) = {add(10, 5)}")
print(f"subtract(10, 5) = {subtract(10, 5)}")
print(f"multiply(10, 5) = {multiply(10, 5)}")
print(f"divide(10, 5) = {divide(10, 5)}")

# %% [markdown]
# ## Part 2: Create a Menu Display Function
#
# Write a function that displays the calculator menu. It should print the available operations.

# %%
# Function: displayMenu
# Your code here
# Print:
# ===== Simple Calculator =====
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Exit
# ==========================

displayMenu()

# %% [markdown]
# ## Part 3: Create a Function That Performs Calculation
#
# Write a function that takes an operation number and two operands, then calls the appropriate operation function.

# %%
# Function: performCalculation
# Parameters: operation (1-4), num1, num2
# Returns: result
# Your code here
# Use if-elif to determine which function to call

# Test it
result = performCalculation(1, 10, 5)  # Should call add
print(f"Operation 1 with 10, 5: {result}")

result = performCalculation(4, 20, 4)  # Should call divide
print(f"Operation 4 with 20, 4: {result}")

# %% [markdown]
# ## Part 4: Create the Main Calculator Program
#
# Write the main program that ties everything together using a loop.

# %%
# Function: runCalculator
# Your code here
# This should:
# 1. Loop until user chooses exit (5)
# 2. Display menu
# 3. Get user input for operation (1-5)
# 4. If not 5:
#    - Get two numbers
#    - Call performCalculation
#    - Display result
# 5. If 5: print goodbye and break

# Note: Use input() to get user input
# Example: operation = int(input("Choose operation: "))

# Uncomment to test
# runCalculator()

# %% [markdown]
# ## Part 5: Test the Complete Program (Demo)
#
# This cell shows what the complete program should do. Run the cell above to test interactively, or uncomment below for a demo.

# %%
# Demo: Simulating what the calculator should do
print("=== CALCULATOR DEMO ===")
print()

# Simulate operation 1: Add
displayMenu()
print("Choose operation: 1")
print("Enter first number: 15")
print("Enter second number: 8")
result = performCalculation(1, 15, 8)
print(f"Result: {result}")
print()

# Simulate operation 3: Multiply
print("Choose operation: 3")
print("Enter first number: 7")
print("Enter second number: 6")
result = performCalculation(3, 7, 6)
print(f"Result: {result}")

# %% [markdown]
# ## Summary
#
# Your calculator demonstrates:
# 1. **Function composition** — Small functions (add, subtract, etc.)
# 2. **Function organization** — Functions doing one thing well
# 3. **Functions calling functions** — performCalculation calls operation functions
# 4. **Main program** — runCalculator orchestrates everything
# 5. **Separation of concerns** — Display, calculation, and control are separate
#
# This is professional code structure!
